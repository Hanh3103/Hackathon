# %%
import os
import pandas as pd
import pickle as pk

# %%
path_input_data = os.path.join('.', 'test.csv')

df = pd.read_csv(path_input_data, delimiter=',')
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.004723 -0.126846 -0.503617 -0.018160 -0.066610  0.284444 -0.016991
# 1    -0.062151  0.369481  0.624042 -0.391315  1.598571 -0.582238 -1.758562
# 2    -0.042649 -0.085708 -0.243738  0.057793 -0.127627 -0.039737 -0.200011
# 3     0.117188  0.090009 -0.061082  0.163556 -0.331647 -0.415064  0.427508
# 4    -0.015573 -0.087727 -0.416550 -0.004744  0.001667  0.086394 -0.036356
# ...        ...       ...       ...       ...       ...       ...       ...
# 1001 -0.064066  0.062538  1.075540 -0.007371 -0.216425  0.201602 -0.116916
# 1002 -0.021456 -0.071265 -0.208805  0.091330 -0.202523 -0.316797 -0.304367
# 1003 -0.003137  0.090104  0.165438 -0.091658  0.308864 -0.289710  0.545499
# 1004 -0.048783 -0.076085 -0.125627  0.017223 -0.104721  0.223286 -0.128321
# 1005 -0.035076 -0.065372 -0.066432  0.054209 -0.318577  0.271628 -0.110117
#
# ...
